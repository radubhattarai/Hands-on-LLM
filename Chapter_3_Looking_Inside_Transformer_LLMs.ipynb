# %% [markdown]
# <a href="https://colab.research.google.com/github/radubhattarai/Hands-on-LLM/blob/main/Chapter_3_Looking_Inside_Transformer_LLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 3 - Looking Inside Transformer LLMs

# %% [markdown]
# In this chapter im going to learn about **'How Transformer Language Model Works?'**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Loading the LLM

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")

model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=False,
)

# Create a pipeline
generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
    max_new_tokens=50,
    do_sample=False,
)

# %% [markdown]
# #The Inputs and Outputs of a Trained Transformer LLM

# %%
prompt = "Write an email apologizing to my girlfriend Aarya for the cheating on her. Explain how it happened."

output = generator(prompt)

print(output[0]['generated_text'])

# %%
print(model)

# %%
prompt = "The capital of Nepal is"

# Tokenize the input prompt
input_ids = tokenizer(prompt, return_tensors="pt").input_ids

# Tokenize the input prompt
input_ids = input_ids.to("cuda")

# Get the output of the model before the lm_head
model_output = model.model(input_ids)

# Get the output of the lm_head
lm_head_output = model.lm_head(model_output[0])

# %%
token_id = lm_head_output[0,-1].argmax(-1)
tokenizer.decode(token_id)

# %%
model_output[0].shape

# %%
lm_head_output.shape

# %% [markdown]
# #Speeding up generation by caching keys and values

# %% [markdown]
# KV Caching saves the model's previous thinking (Keys and Values) so it doesn't have to recalculate them when generating each new token, making text generation about 5 times faster!

# %%
prompt = "Write a very long email apologizing to Sarah for the tragic gardening mishap. Explain how it happened."

# Tokenize the input prompt
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
input_ids = input_ids.to("cuda")

# %%
# %%timeit -n 1
# Generate the text
generation_output = model.generate(
  input_ids=input_ids,
  max_new_tokens=100,
  use_cache=True
)

# %%
# %%timeit -n 1
# Generate the text
generation_output = model.generate(
  input_ids=input_ids,
  max_new_tokens=100,
  use_cache=False
)
